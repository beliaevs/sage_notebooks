# %%
QP.<X>=QQ[]

# %%
SF.<g>=(X^5-4*X+2).splitting_field()

# %%
SF.galois_group()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:10389)()
#    1942             try:
# -> 1943                 return cache[k]
#    1944             except TypeError:  # k is not hashable
#
# ...

# %%
K.<b> = NumberField(x^5 - 4*x+2, 'a')

# %%
K.galois_group()
# Out:
# Galois group 5T5 (S5) with order 120 of x^5 - 4*x + 2

# %%
factor(X^5-4*X+2)
# Out:
# X^5 - 4*X + 2

# %%
SF.degree()
# Out:
# 120

# %%
SF
# Out:
# Number Field in g with defining polynomial X^120 + 60*X^119 + 2918*X^118 + 101608*X^117 + 3086037*X^116 + 79774180*X^115 + 1868414390*X^114 + 39426153790*X^113 + 770743528672*X^112 + 13949107330428*X^111 + 237243874129030*X^110 + 3794613430858000*X^109 + 57596266605194923*X^108 + 830497681829704764*X^107 + 11444083005540285758*X^106 + 150863684441628431402*X^105 + 1910511371027767995915*X^104 + 23264307142317701913800*X^103 + 273224281238870595098984*X^102 + 3097362940523221547018748*X^101 + 33970367220727060506989264*X^100 + 360696008932597933071236404*X^99 + 3714372075582010138369348524*X^98 + 37117535893529457117459887572*X^97 + 360441150193480132110394708449*X^96 + 3402939682228634818740776034108*X^95 + 31270498804893276834234683927002*X^94 + 279796783804273870884355082667680*X^93 + 2439987435111486799948331620915177*X^92 + 20744638832788918987350470825635724*X^91 + 172084547670691311235037316770778354*X^90 + 1393179665961048092424743805673105902*X^89 + 11015294805057636096647012
# ...

# %%
CP.<Y>=CC[]

# %%
factor(Y^5-4*Y+2)
# Out:
# (Y - 1.24359639057354) * (Y - 0.508499484657333) * (Y + 0.116791861222982 - 1.43844769532918*I) * (Y + 0.116791861222982 + 1.43844769532918*I) * (Y + 1.51851215278491)

# %%
list_plot([(r[0].real(), r[0].imag()) for r in CP(SF.polynomial()).roots()]) + list_plot([(r[0].real(), r[0].imag()) for r in (Y^5-4*Y+2).roots()], color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a = 0.116791861222982 - 1.43844769532918*I

# %%
a.real()
# Out:
# 0.116791861222982

# %%
a.imag()
# Out:
# -1.43844769532918

# %%
(Y^5-4*Y+2).roots()
# Out:
# [(-1.51851215278491, 1),
#  (0.508499484657333, 1),
#  (1.24359639057354, 1),
#  (-0.116791861222982 - 1.43844769532918*I, 1),
#  (-0.116791861222982 + 1.43844769532918*I, 1)]

# %%
SF3.<h>=(X^3-2).splitting_field()

# %%
SF3.polynomial()
# Out:
# X^6 + 3*X^5 + 6*X^4 + 3*X^3 + 9*X + 9

# %%
list_plot([(r[0].real(), r[0].imag()) for r in CP(SF3.polynomial()).roots()]) + list_plot([(r[0].real(), r[0].imag()) for r in (Y^3-2).roots()], color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
(Y^6 + 3*Y^5 + 6*Y^4 + 3*Y^3 + 9*Y + 9).roots()
# Out:
# [(-1.12996052494744 - 1.95714903975616*I, 1),
#  (-1.12996052494744 - 0.225098232187283*I, 1),
#  (-1.12996052494744 + 0.225098232187283*I, 1),
#  (-1.12996052494744 + 1.95714903975616*I, 1),
#  (0.759921049894873 - 0.866025403784439*I, 1),
#  (0.759921049894873 + 0.866025403784439*I, 1)]
