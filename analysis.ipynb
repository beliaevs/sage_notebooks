# %%
plot((1+1/x)^x, [x, 1, 10])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a = var('a')

# %%
plot3d((1+x)^a, [x, 0, 2], [a, 0, 2]) + plot3d(1+a*x, [x, -1, 1], [a, 0, 2], color='red')
# Out:
# Graphics3d Object
