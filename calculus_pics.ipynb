# %%
plot(x^2, [x, -1, 2], color='blue', aspect_ratio=1)+\
plot((x+1)*(4-1)/3+1, [x, -1, 2], color='green')+\
plot((x-0.5)+0.25, [x, -1, 2], color='red')
# Out:
# Graphics object consisting of 3 graphics primitives
