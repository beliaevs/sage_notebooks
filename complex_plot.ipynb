# %%
x, y = var('x y')

# %%
i^2
# Out:
# -1

# %%
def z(x, y):
    return complex(x, y)

# %%
a = z(1, 2)

# %%
abs(a)
# Out:
# 2.23606797749979

# %%
plot3d(abs(z(x, y)), [x, -1, 1], [y, -1, 1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__complex__ (build/cythonized/sage/symbolic/expression.cpp:40055)()
#    1975         try:
# -> 1976             return self._eval_self(complex)
#    1977         except TypeError:
#
# /usr/lib/python3/dist-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._eval_self (build/cythonized/sage/symbolic/expression.cpp:37593)()
#    1639         else:
# -> 1640             raise TypeError("Cannot evaluate symbolic expression to a numeric value.")
#    1641
#
# TypeError: Cannot evaluate symbolic expression to a numeric value.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
(1+i*2).abs()
# Out:
# 2.23606797749979

# %%
complex(1, 1)
# Out:
# (1+1j)

# %%
arctan2(-1, -1)
# Out:
# -3/4*pi

# %%
help(atan2)
# Out:
# Help on Function_arctan2 in module sage.functions.trig object:
#
# class Function_arctan2(sage.symbolic.function.GinacFunction)
#  |  Method resolution order:
#  |      Function_arctan2
#  |      sage.symbolic.function.GinacFunction
#  |      sage.symbolic.function.BuiltinFunction
#  |      sage.symbolic.function.Function
#  |      sage.structure.sage_object.SageObject
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      The modified arctangent function.
#  |
#  |      Returns the arc tangent (measured in radians) of `y/x`, where
#  |      unlike ``arctan(y/x)``, the signs of both ``x`` and ``y`` are
#  |      considered.  In particular, this function measures the angle
#  |      of a ray through the origin and `(x,y)`, with the positive
#  |      `x`-axis the zero mark, and with output angle `\theta`
#  |      being between `-\pi<\theta<=\pi`.
#  |
#  |      Hence, ``arctan2(y,x) = arctan(y/x)`` only for `x>0`.  One
# ...

# %%
def abssqr(x, y):
    return x^2+y^2

# %%
plot3d(abssqr(x, y), (x, -1, 1), (y, -1, 1))
# Out:
# Graphics3d Object

# %%
cm = colormaps.hsv

# %%
def c(x, y): return float(arctan2(2*x*y, x*x-y*y)/2/pi+0.5)

# %%
plot3d(abssqr(x, y), (x, -1, 1), (y, -1, 1), color=(c, cm)).show()
# Out:
# Graphics3d Object
