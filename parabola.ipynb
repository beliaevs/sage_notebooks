# %%
plot(x^2, [x, -2, 2], color='red', aspect_ratio=1)+circle([0, 0.5], 0.5, color='blue')+circle([0, 2.5], 1.5, color='green')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
r = 5; plot(x^2, [x, -6, 6], color='red', aspect_ratio=1)+circle([0, r^2+0.25], r, color='blue')+circle([0, (r-1)^2+0.25], r-1, color='green')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
plot(x^2, [x, -3, 3], aspect_ratio=1)+circle([0, 1+0.25], 1, color='red')+circle([0, 4+0.25], 2, color='green')
# Out:
# Graphics object consisting of 3 graphics primitives
