# %%
polytopes.snub_cube().show()
# Out:
# Graphics3d Object

# %%
polytopes.snub_dodecahedron(base_ring=AA, backend='normaliz').show()
# Out:
# Graphics3d Object

# %%
# ?polytopes.snub_dodecahedron
# Out:
# Signature:      polytopes.snub_dodecahedron(base_ring=None, backend=None, verbose=False)
# Docstring:
#    Return the snub dodecahedron.
#
#    The snub dodecahedron is an Archimedean solid. It has 92 faces and
#    60 vertices. For more information, see the
#    https://en.wikipedia.org/wiki/Snub_dodecahedron.
#
#    INPUT:
#
#    * "base_ring" -- the ring in which the coordinates will belong to;
#      if it is not provided it will be the real double field
#
#    * "backend" -- the backend to use to create the polytope
#
#    EXAMPLES:
#
#    Only the backend using the optional normaliz package can construct
#    the snub dodecahedron in reasonable time:
#
#       sage: sd = polytopes.snub_dodecahedron(base_ring=AA,      # long time
#       ....:                                  backend='normaliz')
#       sage: sd.f_vector()                       # long time
#       (1, 60, 150, 92, 1)
#       sage: sd.base_ring()                      # long time
#       Algebraic Real Field
#
# ...

# %%
polytopes.truncated_cube().show()
# Out:
# Graphics3d Object

# %%
polytopes.truncated_octahedron().show()
# Out:
# Graphics3d Object
