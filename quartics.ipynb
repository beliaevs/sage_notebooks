# %%
PQ.<X>=QQ[]

# %%
p = X^4+2*X+2

# %%
factor(p)
# Out:
# X^4 + 2*X + 2

# %%
sp = x^4+2*x+2

# %%
plot(sp, [x, -2, 2])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
F2.<g1>=NumberField(X^2-2)

# %%
PF2.<Y>=F2[]

# %%
factor(Y^4+2*Y+2)
# Out:
# Y^4 + 2*Y + 2

# %%
p, q = var('p q')

# %%
x = var('x')

# %%
solve(x^4+p*x+q==0, x)
# Out:
# [x == -1/2*sqrt(1/3)*sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 1/2*sqrt(6*sqrt(1/3)*p/sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 4/3*q/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3) - (1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)), x == -1/2*sqrt(1/3)*sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) + 1/2*sqrt(6*sqrt(1/3)*p/sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 4/3*q/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3) - (1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)), x == 1/2*sqrt(1/3)*sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 1/2*sqrt(-6*sqrt(1/3)*p/sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 4/3*
# ...

# %%
show(solve(x^4+p*x+q==0, x))
# Out:
# [x == -1/2*sqrt(1/3)*sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 1/2*sqrt(6*sqrt(1/3)*p/sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 4/3*q/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3) - (1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)), x == -1/2*sqrt(1/3)*sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) + 1/2*sqrt(6*sqrt(1/3)*p/sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 4/3*q/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3) - (1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)), x == 1/2*sqrt(1/3)*sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 1/2*sqrt(-6*sqrt(1/3)*p/sqrt((4*q + 3*(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(2/3))/(1/2*p^2 + 1/6*sqrt(9*p^4 - 256/3*q^3))^(1/3)) - 4/3*
# ...

# %%
show(solve(x^3+p*x+q==0, x))
# Out:
# [x == 1/6*p*(-I*sqrt(3) + 1)/(-1/2*q + 1/6*sqrt(4/3*p^3 + 9*q^2))^(1/3) - 1/2*(-1/2*q + 1/6*sqrt(4/3*p^3 + 9*q^2))^(1/3)*(I*sqrt(3) + 1), x == 1/6*p*(I*sqrt(3) + 1)/(-1/2*q + 1/6*sqrt(4/3*p^3 + 9*q^2))^(1/3) - 1/2*(-1/2*q + 1/6*sqrt(4/3*p^3 + 9*q^2))^(1/3)*(-I*sqrt(3) + 1), x == -1/3*p/(-1/2*q + 1/6*sqrt(4/3*p^3 + 9*q^2))^(1/3) + (-1/2*q + 1/6*sqrt(4/3*p^3 + 9*q^2))^(1/3)]

# %%
r = var('r')

# %%
show(solve(x^4+p*x^2+q*x+q==0, x))
# Out:
# [x == -1/6*sqrt(6)*sqrt((1/2)^(2/3)*(p^2 - 2*(1/2)^(1/3)*(2*p^3 - 72*p*q + 27*q^2 + 9*sqrt(1/3)*sqrt(-(16*p^4 + 16*(9*p + 16)*q^2 - 27*q^3 - 4*(p^3 + 32*p^2)*q)*q))^(1/3)*p + (1/2)^(2/3)*(2*p^3 - 72*p*q + 27*q^2 + 9*sqrt(1/3)*sqrt(-(16*p^4 + 16*(9*p + 16)*q^2 - 27*q^3 - 4*(p^3 + 32*p^2)*q)*q))^(2/3) + 12*q)/(2*p^3 - 72*p*q + 27*q^2 + 9*sqrt(1/3)*sqrt(-(16*p^4 + 16*(9*p + 16)*q^2 - 27*q^3 - 4*(p^3 + 32*p^2)*q)*q))^(1/3)) - 1/2*sqrt(2*sqrt(6)*(1/2)^(2/3)*q/sqrt((p^2 - 2*(1/2)^(1/3)*(2*p^3 - 72*p*q + 27*q^2 + 9*sqrt(1/3)*sqrt(-(16*p^4 + 16*(9*p + 16)*q^2 - 27*q^3 - 4*(p^3 + 32*p^2)*q)*q))^(1/3)*p + (1/2)^(2/3)*(2*p^3 - 72*p*q + 27*q^2 + 9*sqrt(1/3)*sqrt(-(16*p^4 + 16*(9*p + 16)*q^2 - 27*q^3 - 4*(p^3 + 32*p^2)*q)*q))^(2/3) + 12*q)/(2*p^3 - 72*p*q + 27*q^2 + 9*sqrt(1/3)*sqrt(-(16*p^4 + 16*(9*p + 16)*q^2 - 27*q^3 - 4*(p^3 + 32*p^2)*q)*q))^(1/3)) - 2/3*(1/2)^(2/3)*(p^2 + 12*q)/(2*p^3 - 72*p*q + 27*q^2 + 9*sqrt(1/3)*sqrt(-(16*p^4 + 16*(9*p + 16)*q^2 - 27*q^3 - 4*(p^3 + 32*p^2)*q)*q))^(1/3) -
# ...

# %%
s = var('s')

# %%
show(solve(x^4+p*x^3+q*x^2+r*x+s==0, x))
# Out:
# [x == -1/12*sqrt(6)*sqrt((1/2)^(2/3)*(4*q^2 - 12*p*r + (1/2)^(1/3)*(2*q^3 + 27*p^2*s - 9*(p*r - 4*s)*q + 27*r^2 - 108*q*s + 9*sqrt(2/3*(2*p^3 - 9*p*q)*r^3 + 9*r^4 - 1/3*(p^2*q^2 - 4*q^3)*r^2 + 1/3*(27*p^4 - 144*p^2*q + 128*q^2 + 192*p*r)*s^2 - 256/3*s^3 + 2/3*(2*p^2*q^3 - 8*q^4 + 3*(p^2 - 24*q)*r^2 - (9*p^3*q - 40*p*q^2)*r)*s))^(1/3)*(3*p^2 - 8*q) + 4*(1/2)^(2/3)*(2*q^3 + 27*p^2*s - 9*(p*r - 4*s)*q + 27*r^2 - 108*q*s + 9*sqrt(2/3*(2*p^3 - 9*p*q)*r^3 + 9*r^4 - 1/3*(p^2*q^2 - 4*q^3)*r^2 + 1/3*(27*p^4 - 144*p^2*q + 128*q^2 + 192*p*r)*s^2 - 256/3*s^3 + 2/3*(2*p^2*q^3 - 8*q^4 + 3*(p^2 - 24*q)*r^2 - (9*p^3*q - 40*p*q^2)*r)*s))^(2/3) + 48*s)/(2*q^3 + 27*p^2*s - 9*(p*r - 4*s)*q + 27*r^2 - 108*q*s + 9*sqrt(2/3*(2*p^3 - 9*p*q)*r^3 + 9*r^4 - 1/3*(p^2*q^2 - 4*q^3)*r^2 + 1/3*(27*p^4 - 144*p^2*q + 128*q^2 + 192*p*r)*s^2 - 256/3*s^3 + 2/3*(2*p^2*q^3 - 8*q^4 + 3*(p^2 - 24*q)*r^2 - (9*p^3*q - 40*p*q^2)*r)*s))^(1/3)) - 1/4*p - 1/2*sqrt(1/2*p^2 + 1/2*sqrt(6)*(1/2)^(2/3)*(p^3 - 4*p*q + 8*r)/sqrt((4*q^2 
# ...
