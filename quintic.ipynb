# %%
PQ.<X>=QQ[]

# %%
p = X^5-X-1

# %%
F.<a>=p.splitting_field()

# %%
p.galois_group()
# Out:
# Transitive group number 5 of degree 5

# %%
FP.<Y>=F[]

# %%
fp = FP(p)

# %%
fp.roots()
# Out:
# [(...*a^119 + ...*a^118 + ...*a^117 + ...*a^116 + ...*a^115 + ...*a^114 + ...*a^113 + ...*a^112 + ...*a^111 + ...*a^110 + ...*a^109 + ...*a^108 + ...*a^107 - ...*a^106 + ...*a^105 - ...*a^104 + ...*a^103 - ...*a^102 - ...*a^101 + ...*a^100 - ...*a^99 + ...*a^98 - ...*a^97 + ...*a^96 + ...*a^95 - ...*a^94 + ...*a^93 - ...*a^92 + ...*a^91 - ...*a^90 + ...*a^89 - ...*a^88 + ...*a^87 - ...*a^86 + ...*a^85 - ...*a^84 + ...*a^83 - ...*a^82 + ...*a^81 + ...*a^80 - ...*a^79 + ...*a^78 - ...*a^77 + ...*a^76 - ...*a^75 - ...*a^74 + ...*a^73 - ...*a^72 + ...*a^71 - ...*a^70 + ...*a^69 - ...*a^68 + ...*a^67 - ...*a^66 + ...*a^65 - ...*a^64 + ...*a^63 - ...*a^62 + ...*a^61 - ...*a^60 + ...*a^59 - ...*a^58 + ...*a^57 - ...*a^56 + ...*a^55 - ...*a^54 + ...*a^53 - ...*a^52 + ...*a^51 - ...*a^50 + ...*a^49 - ...*a^48 + ...*a^47 - ...*a^46 + ...*a^45 - ...*a^44 + ...*a^43 - ...*a^42 + ...*a^41 - ...*a^40 + ...*a^39 - ...*a^38 + ...*a^37 - ...*a^36 + ...*a^35 + ...*a^34 - ...*a^33 - ...*a^32 + ...*a^31
# ...

# %%
a^120
# Out:
# -8*a^119 - 45*a^118 - 181*a^117 - 1047*a^116 - 6630*a^115 - 16039*a^114 - 116910*a^113 - 299035*a^112 - 2193653*a^111 - 4596980*a^110 - 15213975*a^109 - 176162539*a^108 + 210278543*a^107 - 3711625661*a^106 + 9120907171*a^105 - 58667654613*a^104 + 33215039528*a^103 + 184061250991*a^102 - 3402629238057*a^101 + 14828962061890*a^100 - 73534404941172*a^99 + 227711271566092*a^98 - 317650710145751*a^97 - 3243978341846250*a^96 + 33022520831514129*a^95 - 211673715862377045*a^94 + 1104496961247701591*a^93 - 5145015388890870564*a^92 + 21869720167819387405*a^91 - 85837652165793457654*a^90 + 310371258125783304030*a^89 - 1034708338109135577853*a^88 + 3187741519106772811282*a^87 - 9072042855296350827041*a^86 + 23397208651068524056596*a^85 - 52116913280505770028024*a^84 + 90533691055311956073936*a^83 - 86718535195871788623784*a^82 - 118157227177662706158820*a^81 + 805226719635307095855757*a^80 - 2203765050403926539685550*a^79 + 4060677998679405062068881*a^78 - 5283435878977990700920961*a^77 + 402812
# ...

# %%
CP.<Z>=CC[]

# %%
cp = CP(p)

# %%
cp.roots()
# Out:
# [(1.16730397826142, 1),
#  (-0.764884433600585 - 0.352471546031726*I, 1),
#  (-0.764884433600585 + 0.352471546031726*I, 1),
#  (0.181232444469875 - 1.08395410131771*I, 1),
#  (0.181232444469875 + 1.08395410131771*I, 1)]

# %%
list_plot([(r[0].real(), r[0].imag()) for r in cp.roots()])
# Out:
# Graphics object consisting of 1 graphics primitive
